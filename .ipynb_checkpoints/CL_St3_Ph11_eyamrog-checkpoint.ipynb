# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 3 - Phase 1_1 - eyamrog

# %% [markdown]
# The aim of this phase is to retrieve data for the dissertation.

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - pandas
# - matplotlib

# %% [markdown]
# ## Import the required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Define input variables

# %%
input_directory = 'cl_st3_ph1_eyamrog'
output_directory = 'cl_st3_ph1_eyamrog'

# %% [markdown]
# ### Import the data into a DataFrame

# %%
df_el2ap = pd.read_json(f"{input_directory}/df_el2ap.jsonl", lines=True)

# %%
df_el2ap['Submitted'] = pd.to_datetime(df_el2ap['Submitted'], unit='ms')
df_el2ap['Posted'] = pd.to_datetime(df_el2ap['Posted'], unit='ms')

# %%
df_el2ap
# Out:
#                                                    Title  \
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 2      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 3      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 4      (Fern flora of Viçosa, Minas Gerais State, Bra...
# ...                                                  ...
# 11131  COVID-19 in Brazil: advantages of a socialized...
# 11132  COVID-19 in Brazil: advantages of a socialized...
# 11133  COVID-19 in Brazil: advantages of a socialized...
# 11134  COVID-19 in Brazil: advantages of a socialized...
# 11135  COVID-19 in Brazil: advantages of a socialized...
#
#                                                      URL  \
# 0      https://preprints.scielo.org/index.php/scielo/...
# 1      https://preprints.scielo.org/index.php/scielo/...
# 2      https://preprints.scielo.org/index.php/scielo/...
# 3      https://preprints.scielo.org/index.php/scielo/...
# 4      https://preprints.scielo.org/index.php/scielo/...
# ...                                                  ...
# 11131  https://preprints.scielo.org/index.php/scielo/...
# 11132  https://preprints.scielo.org/index.php/scielo/...
# 11133  https://preprints.scielo.org/index.php/scielo/...
# 11134  https://preprints.scielo.org/index.php/scielo/...
# 11135  https://preprints.scielo.org/index.php/scielo/...
#
#                                                  Authors  \
# 0        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 2        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 3        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 4        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# ...                                                  ...
# 11131  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11132  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11133  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11134  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11135  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                       Published PDF Language  \
# 0      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 2      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 3      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 4      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# ...                                         ...          ...
# 11131  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11132  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11133  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11134  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11135  Submitted 04/06/2020 - Posted 04/08/2020          PDF
#
#                                                  PDF URL  Submitted  \
# 0      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 1      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 2      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 3      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 4      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# ...                                                  ...        ...
# 11131  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11132  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11133  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11134  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11135  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
#
#           Posted  Text ID           Discipline  \
# 0     2022-11-23  t000000  Biological Sciences
# 1     2022-11-23  t000000  Biological Sciences
# 2     2022-11-23  t000000  Biological Sciences
# 3     2022-11-23  t000000  Biological Sciences
# 4     2022-11-23  t000000  Biological Sciences
# ...          ...      ...                  ...
# 11131 2020-04-08  t000315      Health Sciences
# 11132 2020-04-08  t000315      Health Sciences
# 11133 2020-04-08  t000315      Health Sciences
# 11134 2020-04-08  t000315      Health Sciences
# 11135 2020-04-08  t000315      Health Sciences
#
#                                                  Section     Paragraph  \
# 0                                               Abstract   Paragraph 1
# 1                        Introduction, Literature Review   Paragraph 1
# 2                        Introduction, Literature Review   Paragraph 2
# 3                        Introduction, Literature Review   Paragraph 3
# 4                        Introduction, Literature Review   Paragraph 4
# ...                                                  ...           ...
# 11131  Literature Review, Methodology, Results, Discu...  Paragraph 14
# 11132  Literature Review, Methodology, Results, Discu...  Paragraph 15
# 11133  Literature Review, Methodology, Results, Discu...  Paragraph 16
# 11134  Literature Review, Methodology, Results, Discu...  Paragraph 17
# 11135                                   Acknowledgements   Paragraph 1
#
#                                           Text Paragraph  \
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      At the end of the era in which the plant Class...
# 2      Brazil is represented by Dennstaedtiaceae with...
# 3      Pteridium is spread all across the globe (exce...
# 4      In the State of Minas Gerais, Dennstaedtiaceae...
# ...                                                  ...
# 11131  During the Zika epidemic, Brazil led the disco...
# 11132  Although Brazil is attempting to implement mea...
# 11133  Regarding cultural differences, the use of mas...
# 11134  Physical distancing is a measure that should b...
# 11135  We thank Judith Recht for the critical review ...
#
#                                   Text Paragraph ChatGPT
# 0      As part of an ongoing project focused on the f...
# 1      At the end of the period when plant classifica...
# 2      In Brazil, Dennstaedtiaceae is represented by ...
# 3      Pteridium is distributed globally, with the ex...
# 4      In the state of Minas Gerais, the family Denns...
# ...                                                  ...
# 11131  During the Zika epidemic, Brazil was the first...
# 11132  Although Brazil is implementing measures to re...
# 11133  With respect to cultural differences, the use ...
# 11134  Physical distancing should be recommended at a...
# 11135  We thank Judith Recht for her critical review ...
#
# [11136 rows x 14 columns]

# %% [markdown]
# ## Quantify the articles according to their discipline

# %%
# Remove duplicate (Text ID, Discipline) pairs to count unique texts per discipline
df_unique = df_el2ap.drop_duplicates(subset=['Text ID', 'Discipline'])

# Count occurrences of each unique discipline (the values are automatically sorted in descending order)
df_discipline_counts = df_unique['Discipline'].value_counts().reset_index()

# Rename columns
df_discipline_counts.columns = ['Discipline', 'Number of Texts']

# Display the final DataFrame
df_discipline_counts
# Out:
#                         Discipline  Number of Texts
# 0                  Health Sciences              186
# 1              Biological Sciences               50
# 2                   Human Sciences               27
# 3          Applied Social Sciences               24
# 4  Linguistic, literature and arts               15
# 5                      Engineering                6
# 6         Exact and Earth Sciences                5
# 7            Agricultural Sciences                3

# %%
df_discipline_counts.dtypes
# Out:
# Discipline         object
# Number of Texts     int64
# dtype: object

# %% [markdown]
# ### Plot a bar chat

# %%
x_label = 'Discipline'
y_label = 'Number of Texts'
title = 'Original EL2AP - Number of Texts per Discipline'
filename = 'df_el2ap_texts_per_discipline'
plot_filename = f"{filename}.png"

# %%
# Plot a bar chart
plt.figure(figsize=(10, 5))  # Adjust figure size
plt.bar(df_discipline_counts['Discipline'], df_discipline_counts['Number of Texts'], color='royalblue')

# Formatting
plt.xticks(rotation=45, ha='right')  # Rotate labels for readability
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(title)

# Saving as an image
plt.savefig(f"{output_directory}/{plot_filename}", dpi=300, bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# ### Create a LaTeX table

# %%
caption = title
label = f"tab:{plot_filename}"
tex_filename = f"{filename}.tex"

# %%
tex_table = df_discipline_counts.to_latex(index=False, longtable=True, decimal=',', caption=caption, label=label)
# Use the following line for DataFrames with data types 'float64'
#tex_table = df_discipline_counts.to_latex(index=False, float_format='%.2f', longtable=True, decimal=',', caption=caption, label=label)

# %%
with open(f"{output_directory}/{tex_filename}", 'w', encoding='utf8', newline='\n') as file:
    file.write(tex_table)
