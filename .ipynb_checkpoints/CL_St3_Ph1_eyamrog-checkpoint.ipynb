# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 3 - Phase 1 - eyamrog

# %% [markdown]
# This phase aims to compile the EL2AP corpus (Human-Authored Target Corpus).
#
# - **Definition of text**:
#     - Academic research articles;
#     - Organised in sections: Abstract, Introduction, Literature Review, Methodology, Results, Discussion, Conclusion, Acknowledgements;
#     - Paragraphs longer than or equal to 10 words.

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - pandas
# - nltk

# %% [markdown]
# ## Importing the required libraries

# %%
import pandas as pd
import os
import sys
import nltk
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Defining input variables

# %%
input_directory = 'cl_st3_ph1_eyamrog'
output_directory = 'cl_st3_ph1_eyamrog'

# %% [markdown]
# ## Create output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)
# Out:
# Output directory already exists.

# %% [markdown]
# ### Import the data into a DataFrame

# %%
df_el2ap = pd.read_json(f"{input_directory}/scielo_chatgpt_erpp_pp.jsonl", lines=True)

# %%
df_el2ap.dtypes
# Out:
# Title                     object
# URL                       object
# Authors                   object
# Published                 object
# PDF Language              object
# PDF URL                   object
# Submitted                  int64
# Posted                     int64
# Text ID                   object
# Area of Knowledge         object
# Section                   object
# Paragraph                 object
# Text Paragraph            object
# Text Paragraph ChatGPT    object
# dtype: object

# %%
df_el2ap['Submitted'] = pd.to_datetime(df_el2ap['Submitted'], unit='ms')
df_el2ap['Posted'] = pd.to_datetime(df_el2ap['Posted'], unit='ms')

# %% [markdown]
# #### Renaming the column `Area of Knowledge` to `Discipline`

# %%
df_el2ap.rename(columns={
    'Area of Knowledge': 'Discipline'
}, inplace=True)

# %%
df_el2ap
# Out:
#                                                    Title  \
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 2      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 3      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 4      (Fern flora of Viçosa, Minas Gerais State, Bra...
# ...                                                  ...
# 11522  COVID-19 in Brazil: advantages of a socialized...
# 11523  COVID-19 in Brazil: advantages of a socialized...
# 11524  COVID-19 in Brazil: advantages of a socialized...
# 11525  COVID-19 in Brazil: advantages of a socialized...
# 11526  COVID-19 in Brazil: advantages of a socialized...
#
#                                                      URL  \
# 0      https://preprints.scielo.org/index.php/scielo/...
# 1      https://preprints.scielo.org/index.php/scielo/...
# 2      https://preprints.scielo.org/index.php/scielo/...
# 3      https://preprints.scielo.org/index.php/scielo/...
# 4      https://preprints.scielo.org/index.php/scielo/...
# ...                                                  ...
# 11522  https://preprints.scielo.org/index.php/scielo/...
# 11523  https://preprints.scielo.org/index.php/scielo/...
# 11524  https://preprints.scielo.org/index.php/scielo/...
# 11525  https://preprints.scielo.org/index.php/scielo/...
# 11526  https://preprints.scielo.org/index.php/scielo/...
#
#                                                  Authors  \
# 0        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 2        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 3        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 4        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# ...                                                  ...
# 11522  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11523  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11524  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11525  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11526  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                       Published PDF Language  \
# 0      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 2      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 3      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 4      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# ...                                         ...          ...
# 11522  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11523  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11524  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11525  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11526  Submitted 04/06/2020 - Posted 04/08/2020          PDF
#
#                                                  PDF URL  Submitted  \
# 0      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 1      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 2      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 3      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 4      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# ...                                                  ...        ...
# 11522  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11523  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11524  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11525  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11526  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
#
#           Posted  Text ID           Discipline  \
# 0     2022-11-23  t000000  Biological Sciences
# 1     2022-11-23  t000000  Biological Sciences
# 2     2022-11-23  t000000  Biological Sciences
# 3     2022-11-23  t000000  Biological Sciences
# 4     2022-11-23  t000000  Biological Sciences
# ...          ...      ...                  ...
# 11522 2020-04-08  t000315      Health Sciences
# 11523 2020-04-08  t000315      Health Sciences
# 11524 2020-04-08  t000315      Health Sciences
# 11525 2020-04-08  t000315      Health Sciences
# 11526 2020-04-08  t000315      Health Sciences
#
#                                                  Section     Paragraph  \
# 0                                               Abstract   Paragraph 1
# 1                        Introduction, Literature Review   Paragraph 1
# 2                        Introduction, Literature Review   Paragraph 2
# 3                        Introduction, Literature Review   Paragraph 3
# 4                        Introduction, Literature Review   Paragraph 4
# ...                                                  ...           ...
# 11522  Literature Review, Methodology, Results, Discu...  Paragraph 14
# 11523  Literature Review, Methodology, Results, Discu...  Paragraph 15
# 11524  Literature Review, Methodology, Results, Discu...  Paragraph 16
# 11525  Literature Review, Methodology, Results, Discu...  Paragraph 17
# 11526                                   Acknowledgements   Paragraph 1
#
#                                           Text Paragraph  \
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      At the end of the era in which the plant Class...
# 2      Brazil is represented by Dennstaedtiaceae with...
# 3      Pteridium is spread all across the globe (exce...
# 4      In the State of Minas Gerais, Dennstaedtiaceae...
# ...                                                  ...
# 11522  During the Zika epidemic, Brazil led the disco...
# 11523  Although Brazil is attempting to implement mea...
# 11524  Regarding cultural differences, the use of mas...
# 11525  Physical distancing is a measure that should b...
# 11526  We thank Judith Recht for the critical review ...
#
#                                   Text Paragraph ChatGPT
# 0      As part of an ongoing project focused on the f...
# 1      At the end of the period when plant classifica...
# 2      In Brazil, Dennstaedtiaceae is represented by ...
# 3      Pteridium is distributed globally, with the ex...
# 4      In the state of Minas Gerais, the family Denns...
# ...                                                  ...
# 11522  During the Zika epidemic, Brazil was the first...
# 11523  Although Brazil is implementing measures to re...
# 11524  With respect to cultural differences, the use ...
# 11525  Physical distancing should be recommended at a...
# 11526  We thank Judith Recht for her critical review ...
#
# [11527 rows x 14 columns]

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Paragraphs that could not be interpreted by ChatGPT

# %% [markdown]
# Those paragraphs are identified by the following ChatGPT responses:
# - 'Of course. Please provide the passage **you would like me to improve**.'
# - 'It appears that your message is incomplete. Please provide the passage **you would like me to improve**.'
# - 'Certainly. Please provide the passage **you would like me to improve**.'
# - 'Certainly! Please provide the passage **you would like me to improve**.'

# %%
# Get the indexes of rows containing the phrase 'you would like me to improve'
index_list_with_phrase = df_el2ap[df_el2ap['Text Paragraph ChatGPT'].str.contains('you would like me to improve', na=False)].index.tolist()

# %%
len(index_list_with_phrase)
# Out:
# 20

# %%
print(index_list_with_phrase)
# Out:
# [3411, 3429, 4877, 5043, 5066, 5075, 6612, 6624, 6626, 6628, 6630, 6634, 6636, 6638, 6645, 6647, 7743, 7918, 8165, 10073]

# %% [markdown]
# ### Paragraphs shorter than 10 words

# %%
# Slice the DataFrame where 'Text Paragraph' contains fewer than 10 words
df_less_than_10_words = df_el2ap[df_el2ap['Text Paragraph'].apply(lambda x: len(str(x).split())) < 10]

# %%
# Write the contents of the column 'Text Paragraph' to a text file
df_less_than_10_words['Text Paragraph'].to_csv(f"{output_directory}/df_less_than_10_words.txt", index=False, header=False)

# %%
# Get the indexes of rows where 'Text Paragraph' contains less than 10 words
index_list_less_than_10_words = df_el2ap[df_el2ap['Text Paragraph'].apply(lambda x: len(str(x).split())) < 10].index.tolist()

# %%
len(index_list_less_than_10_words)
# Out:
# 391

# %% [markdown]
# ### Consolidate an index list for filtering the DataFrame

# %%
# Merge the two lists, remove duplicates, and sort in descending order
index_list_for_filtering = sorted(set(index_list_with_phrase + index_list_less_than_10_words), reverse=True)

# %%
len(index_list_for_filtering)
# Out:
# 391

# %% [markdown]
# ### Dropping the filtered rows

# %%
df_el2ap.drop(index_list_for_filtering, inplace=True)

# %%
df_el2ap
# Out:
#                                                    Title  \
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 2      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 3      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 4      (Fern flora of Viçosa, Minas Gerais State, Bra...
# ...                                                  ...
# 11522  COVID-19 in Brazil: advantages of a socialized...
# 11523  COVID-19 in Brazil: advantages of a socialized...
# 11524  COVID-19 in Brazil: advantages of a socialized...
# 11525  COVID-19 in Brazil: advantages of a socialized...
# 11526  COVID-19 in Brazil: advantages of a socialized...
#
#                                                      URL  \
# 0      https://preprints.scielo.org/index.php/scielo/...
# 1      https://preprints.scielo.org/index.php/scielo/...
# 2      https://preprints.scielo.org/index.php/scielo/...
# 3      https://preprints.scielo.org/index.php/scielo/...
# 4      https://preprints.scielo.org/index.php/scielo/...
# ...                                                  ...
# 11522  https://preprints.scielo.org/index.php/scielo/...
# 11523  https://preprints.scielo.org/index.php/scielo/...
# 11524  https://preprints.scielo.org/index.php/scielo/...
# 11525  https://preprints.scielo.org/index.php/scielo/...
# 11526  https://preprints.scielo.org/index.php/scielo/...
#
#                                                  Authors  \
# 0        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 2        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 3        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 4        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# ...                                                  ...
# 11522  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11523  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11524  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11525  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11526  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                       Published PDF Language  \
# 0      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 2      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 3      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 4      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# ...                                         ...          ...
# 11522  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11523  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11524  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11525  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11526  Submitted 04/06/2020 - Posted 04/08/2020          PDF
#
#                                                  PDF URL  Submitted  \
# 0      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 1      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 2      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 3      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 4      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# ...                                                  ...        ...
# 11522  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11523  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11524  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11525  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11526  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
#
#           Posted  Text ID           Discipline  \
# 0     2022-11-23  t000000  Biological Sciences
# 1     2022-11-23  t000000  Biological Sciences
# 2     2022-11-23  t000000  Biological Sciences
# 3     2022-11-23  t000000  Biological Sciences
# 4     2022-11-23  t000000  Biological Sciences
# ...          ...      ...                  ...
# 11522 2020-04-08  t000315      Health Sciences
# 11523 2020-04-08  t000315      Health Sciences
# 11524 2020-04-08  t000315      Health Sciences
# 11525 2020-04-08  t000315      Health Sciences
# 11526 2020-04-08  t000315      Health Sciences
#
#                                                  Section     Paragraph  \
# 0                                               Abstract   Paragraph 1
# 1                        Introduction, Literature Review   Paragraph 1
# 2                        Introduction, Literature Review   Paragraph 2
# 3                        Introduction, Literature Review   Paragraph 3
# 4                        Introduction, Literature Review   Paragraph 4
# ...                                                  ...           ...
# 11522  Literature Review, Methodology, Results, Discu...  Paragraph 14
# 11523  Literature Review, Methodology, Results, Discu...  Paragraph 15
# 11524  Literature Review, Methodology, Results, Discu...  Paragraph 16
# 11525  Literature Review, Methodology, Results, Discu...  Paragraph 17
# 11526                                   Acknowledgements   Paragraph 1
#
#                                           Text Paragraph  \
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      At the end of the era in which the plant Class...
# 2      Brazil is represented by Dennstaedtiaceae with...
# 3      Pteridium is spread all across the globe (exce...
# 4      In the State of Minas Gerais, Dennstaedtiaceae...
# ...                                                  ...
# 11522  During the Zika epidemic, Brazil led the disco...
# 11523  Although Brazil is attempting to implement mea...
# 11524  Regarding cultural differences, the use of mas...
# 11525  Physical distancing is a measure that should b...
# 11526  We thank Judith Recht for the critical review ...
#
#                                   Text Paragraph ChatGPT
# 0      As part of an ongoing project focused on the f...
# 1      At the end of the period when plant classifica...
# 2      In Brazil, Dennstaedtiaceae is represented by ...
# 3      Pteridium is distributed globally, with the ex...
# 4      In the state of Minas Gerais, the family Denns...
# ...                                                  ...
# 11522  During the Zika epidemic, Brazil was the first...
# 11523  Although Brazil is implementing measures to re...
# 11524  With respect to cultural differences, the use ...
# 11525  Physical distancing should be recommended at a...
# 11526  We thank Judith Recht for her critical review ...
#
# [11136 rows x 14 columns]

# %% [markdown]
# ### Minimum and maximum paragraph lengths in the column `Text Paragraph`

# %%
# Calculate the length of each paragraph
paragraph_lengths = df_el2ap['Text Paragraph'].apply(lambda x: len(str(x).split()))

# Get the minimum and maximum lengths
min_length = paragraph_lengths.min()
max_length = paragraph_lengths.max()

# Display the results
min_length, max_length
# Out:
# (10, 503)

# %% [markdown]
# ### Minimum and maximum paragraph lengths in the column `Text Paragraph ChatGPT`

# %%
# Calculate the length of each paragraph
paragraph_lengths_chatgpt = df_el2ap['Text Paragraph ChatGPT'].apply(lambda x: len(str(x).split()))

# Get the minimum and maximum lengths
min_length_chatgpt = paragraph_lengths.min()
max_length_chatgpt = paragraph_lengths.max()

# Display the results
min_length_chatgpt, max_length_chatgpt
# Out:
# (10, 503)

# %% [markdown]
# ### Identifying characters that could be problematic for processing

# %% [markdown]
# #### In column `Text Paragraph`

# %%
# Combine all paragraphs into a single string
combined_text = ''.join(df_el2ap['Text Paragraph'].dropna())

# Get the set of unique characters
unique_characters = set(combined_text)

# Display the set of characters
print(unique_characters)
# Out:
# {'\uf05b', '𝑎', 'x', '±', '̃', '𝐴', 'ß', '£', 's', 'Š', '́', ',', '2', '0', '<', '𝑋', '𝑍', '𝑏', 'R', '𝜃', 'i', 'ω', '©', 'ż', 'F', '˜', '\uf06c', '\uf05d', 'm', '5', 'À', 'Ñ', '!', 'Ɣ', '8', 'G', 'ĩ', '>', 'θ', '\uf0a3', '𝑗', 'ć', 'W', '\uf0d2', '𝐼', '𝒇', '≠', '(', 'º', '≤', '⋅', '¸', '⋯', 'Ú', 'T', '&', 'ﬀ', '𝜑', '«', '𝑊', '𝐷', '𝑦', 'ñ', '𝑓', '“', 'ϒ', '.', '≥', 'ℛ', '[', 'κ', 'É', '∙', 'ê', 'ˆ', 'ũ', ';', '€', 'λ', '𝑣', '𝑥', '³', 'p', '°', '𝐺', 'w', 'μ', '𝑐', '•', 'e', 'b', 'α', 'ﬂ', '℃', '∼', '"', 'ï', '𝜏', '6', '𝑛', 'Ã', '…', 'â', '𝑘', '²', 'İ', 'Å', 'é', 'ε', '‒', 'n', 'V', '`', '®', '=', 'ø', '′', 'Í', 'u', '𝑒', '𝑡', 'j', 'g', '/', '∆', '1', '3', '𝑠', ' ', 'ǧ', '𝜇', 'o', '𝛼', 'h', 'ş', 'ı', '𝜌', 'M', '𝐵', 'ó', 'I', 'Ç', '̅', '¹', '𝒊', 'γ', 'φ', '❤', '∞', 'č', 'U', 'Ö', 'Ⓡ', 't', 'K', '𝑧', '𝜅', '#', ')', '\xad', 'a', '–', 'd', '𝑟', '\u200b', '●', 'y', 'X', ':', '‐', ']', '¨', '+', '𝑚', '𝛾', 'H', '™', 'ś', 'O', 'σ', 'ô', 'ﬁ', '𝑝', 'ğ', 'π', '𝑜', 'J', 'ë', 'S', 'Ć', 'f', '𝑃', '”', 'β', 'r', '\uf0b1', '{', 'ò', 'Δ', '-', 'Ê', 'c', '𝜂', '|', 'ì', '·', 'µ', '»', 'P', '4', '𝛹', 'í', '𝑢', '}', '𝑙', 'E', "'", '𝜎', 'Ü', 'å', '𝑖', 'Φ', '𝑇', '⇒', '¼', 'Y', '𝑀', 'δ', '𝜀', 'ö', '∗', '𝜔', 'ɳ', 'z', '𝜖', '_', '𝝌', 'Z', '𝛽', '𝑔', '̧', 'L', '−', 'ρ', '˚', 'ú', '𝐹', 'B', 'Ğ', 'χ', 'ç', 'Ᾰ', '𝐻', 'ł', 'ã', 'k', 'η', '𝑞', '„', 'ª', 'ℎ', '*', '𝑑', 'D', 'ä', 'è', '§', 'l', '№', '″', '’', 'Ó', '𝜆', '‑', '×', 'N', 'š', 'ť', '´', '≅', '𝒙', '%', 'à', 'Ø', '9', '𝛥', 'C', '―', 'Á', '𝜋', '𝑅', '@', '𝐶', '↓', '\\', '∈', 'q', '∋', 'ü', 'á', '?', 'õ', '—', '𝑆', 'v', 'Õ', 'Ω', '$', 'Ε', 'A', 'ý', '7', 'τ', '𝑤', 'ﬃ', 'Q', '~', '∑', '½', '‘'}

# %% [markdown]
# #### In column `Text Paragraph ChatGPT`

# %%
# Combine all paragraphs into a single string
combined_text_chatgpt = ''.join(df_el2ap['Text Paragraph ChatGPT'].dropna())

# Get the set of unique characters
unique_characters_chatgpt = set(combined_text)

# Display the set of characters
print(unique_characters_chatgpt)
# Out:
# {'\uf05b', '𝑎', 'x', '±', '̃', '𝐴', 'ß', '£', 's', 'Š', '́', ',', '2', '0', '<', '𝑋', '𝑍', '𝑏', 'R', '𝜃', 'i', 'ω', '©', 'ż', 'F', '˜', '\uf06c', '\uf05d', 'm', '5', 'À', 'Ñ', '!', 'Ɣ', '8', 'G', 'ĩ', '>', 'θ', '\uf0a3', '𝑗', 'ć', 'W', '\uf0d2', '𝐼', '𝒇', '≠', '(', 'º', '≤', '⋅', '¸', '⋯', 'Ú', 'T', '&', 'ﬀ', '𝜑', '«', '𝑊', '𝐷', '𝑦', 'ñ', '𝑓', '“', 'ϒ', '.', '≥', 'ℛ', '[', 'κ', 'É', '∙', 'ê', 'ˆ', 'ũ', ';', '€', 'λ', '𝑣', '𝑥', '³', 'p', '°', '𝐺', 'w', 'μ', '𝑐', '•', 'e', 'b', 'α', 'ﬂ', '℃', '∼', '"', 'ï', '𝜏', '6', '𝑛', 'Ã', '…', 'â', '𝑘', '²', 'İ', 'Å', 'é', 'ε', '‒', 'n', 'V', '`', '®', '=', 'ø', '′', 'Í', 'u', '𝑒', '𝑡', 'j', 'g', '/', '∆', '1', '3', '𝑠', ' ', 'ǧ', '𝜇', 'o', '𝛼', 'h', 'ş', 'ı', '𝜌', 'M', '𝐵', 'ó', 'I', 'Ç', '̅', '¹', '𝒊', 'γ', 'φ', '❤', '∞', 'č', 'U', 'Ö', 'Ⓡ', 't', 'K', '𝑧', '𝜅', '#', ')', '\xad', 'a', '–', 'd', '𝑟', '\u200b', '●', 'y', 'X', ':', '‐', ']', '¨', '+', '𝑚', '𝛾', 'H', '™', 'ś', 'O', 'σ', 'ô', 'ﬁ', '𝑝', 'ğ', 'π', '𝑜', 'J', 'ë', 'S', 'Ć', 'f', '𝑃', '”', 'β', 'r', '\uf0b1', '{', 'ò', 'Δ', '-', 'Ê', 'c', '𝜂', '|', 'ì', '·', 'µ', '»', 'P', '4', '𝛹', 'í', '𝑢', '}', '𝑙', 'E', "'", '𝜎', 'Ü', 'å', '𝑖', 'Φ', '𝑇', '⇒', '¼', 'Y', '𝑀', 'δ', '𝜀', 'ö', '∗', '𝜔', 'ɳ', 'z', '𝜖', '_', '𝝌', 'Z', '𝛽', '𝑔', '̧', 'L', '−', 'ρ', '˚', 'ú', '𝐹', 'B', 'Ğ', 'χ', 'ç', 'Ᾰ', '𝐻', 'ł', 'ã', 'k', 'η', '𝑞', '„', 'ª', 'ℎ', '*', '𝑑', 'D', 'ä', 'è', '§', 'l', '№', '″', '’', 'Ó', '𝜆', '‑', '×', 'N', 'š', 'ť', '´', '≅', '𝒙', '%', 'à', 'Ø', '9', '𝛥', 'C', '―', 'Á', '𝜋', '𝑅', '@', '𝐶', '↓', '\\', '∈', 'q', '∋', 'ü', 'á', '?', 'õ', '—', '𝑆', 'v', 'Õ', 'Ω', '$', 'Ε', 'A', 'ý', '7', 'τ', '𝑤', 'ﬃ', 'Q', '~', '∑', '½', '‘'}

# %% [markdown]
# ### Export to a file

# %%
df_el2ap.to_json(f"{output_directory}/df_el2ap.jsonl", orient='records', lines=True)

# %%
df_el2ap.to_excel(f"{output_directory}/df_el2ap.xlsx")

# %% [markdown]
# ## Balance the corpus

# %% [markdown]
# ### Import the data into a DataFrame

# %%
df_el2ap = pd.read_json(f"{output_directory}/df_el2ap.jsonl", lines=True)

# %%
df_el2ap['Submitted'] = pd.to_datetime(df_el2ap['Submitted'], unit='ms')
df_el2ap['Posted'] = pd.to_datetime(df_el2ap['Posted'], unit='ms')

# %% [markdown]
# ### Balance the `Discipline` stratum

# %%
# Group by 'Discipline' and calculate the required metrics
df_balancing = df_el2ap.groupby('Discipline').agg(
    Text_Counts=('Text ID', lambda x: x.nunique()),  # Count unique Text IDs
    Paragraph_Counts=('Text ID', 'size')  # Count number of paragraphs (rows)
).reset_index()

# Rename the columns
df_balancing.rename(columns={
    'Text_Counts': 'Text Counts',
    'Paragraph_Counts': 'Paragraph Counts'
}, inplace=True)

# Sort the DataFrame by 'Paragraph Counts' in descending order
df_balancing = df_balancing.sort_values(by='Paragraph Counts', ascending=False).reset_index(drop=True)

# Add 'Average Paragraph Count per Text'
df_balancing['Average Paragraph Count per Text'] = df_balancing['Paragraph Counts'] / df_balancing['Text Counts']

# Add 'Balanced Paragraph Counts' using direct computation with the index
df_balancing['Balanced Paragraph Counts'] = df_balancing['Paragraph Counts'] * (df_balancing.index + 1)

# Display the DataFrame
df_balancing
# Out:
#                         Discipline  Text Counts  Paragraph Counts  \
# 0                  Health Sciences          186              5431
# 1              Biological Sciences           50              1492
# 2                   Human Sciences           27              1283
# 3          Applied Social Sciences           24              1272
# 4  Linguistic, literature and arts           15              1030
# 5         Exact and Earth Sciences            5               300
# 6                      Engineering            6               213
# 7            Agricultural Sciences            3               115
#
#    Average Paragraph Count per Text  Balanced Paragraph Counts
# 0                         29.198925                       5431
# 1                         29.840000                       2984
# 2                         47.518519                       3849
# 3                         53.000000                       5088
# 4                         68.666667                       5150
# 5                         60.000000                       1800
# 6                         35.500000                       1491
# 7                         38.333333                        920

# %%
df_balancing.dtypes
# Out:
# Discipline                           object
# Text Counts                           int64
# Paragraph Counts                      int64
# Average Paragraph Count per Text    float64
# Balanced Paragraph Counts             int64
# dtype: object

# %%
x_label = 'Number of Disciplines'
y_label = 'Balanced Paragraph Counts'
title = 'Balanced Paragraph Counts versus Number of Disciplines'
filename = 'df_el2ap_balanced_paragraph_counts_versus_number_of_disciplines'
plot_filename = f"{filename}.png"

# %%
import matplotlib.pyplot as plt

# X-axis: Index + 1
x_axis = df_balancing.index + 1

# Y-axis: Balanced Paragraph Counts
y_axis = df_balancing['Balanced Paragraph Counts']

# Disciplines for labels
labels = df_balancing['Discipline']

# Plotting the bar plot
plt.figure(figsize=(10, 6))
plt.bar(x_axis, y_axis, color='royalblue')

# Adjust the y-axis range
plt.ylim(0, y_axis.max() * 1.4)  # Extend y-axis to 40% above the maximum value

# Adding labels and title
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(title)
plt.xticks(x_axis)  # Ensure all indices are shown

# Adding the labels for each bar
for i, label in enumerate(labels):
    plt.text(x=x_axis[i], y=y_axis[i] + (y_axis.max() * 0.02), s=label, ha='center', va='bottom', fontsize=8, rotation=45)

# Saving as an image
plt.savefig(f"{output_directory}/{plot_filename}", dpi=300, bbox_inches="tight")

# Show the plot
plt.show()

# %% [markdown]
# #### Create a LaTeX table

# %%
caption = title
label = f"tab:{filename}"
tex_filename = f"{filename}.tex"

# %%
tex_table = df_balancing.to_latex(index=False, longtable=True, decimal=',', caption=caption, label=label)

# %%
with open(f"{output_directory}/{tex_filename}", 'w', encoding='utf8', newline='\n') as file:
    file.write(tex_table)

# %% [markdown]
# Ideally, the corpus should be balanced according to the discipline contributing the least with paragraphs. However, if the least contributing discipline, `Agricultural Sciences`, is considered, the number of disciplines will be maintained, but the number of paragraphs of the corpus will be the lowest. The proposed solution consists of excluding the least contributing disciplines: `Engineering`, `Exact and Earth Sciences` and `Agricultural Sciences`. Balancing the corpus with the number of paragraphs of `Linguistic, literature and arts` results in the largest number of paragraphs with the least reduction in the number of disciplines.

# %%
# Exclude rows based on the specified values in the 'Discipline' column
df_el2ap_balanced = df_el2ap[~df_el2ap['Discipline'].isin(['Engineering', 'Exact and Earth Sciences', 'Agricultural Sciences'])]

# Display the new DataFrame
df_el2ap_balanced
# Out:
#                                                    Title  \
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 2      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 3      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 4      (Fern flora of Viçosa, Minas Gerais State, Bra...
# ...                                                  ...
# 11131  COVID-19 in Brazil: advantages of a socialized...
# 11132  COVID-19 in Brazil: advantages of a socialized...
# 11133  COVID-19 in Brazil: advantages of a socialized...
# 11134  COVID-19 in Brazil: advantages of a socialized...
# 11135  COVID-19 in Brazil: advantages of a socialized...
#
#                                                      URL  \
# 0      https://preprints.scielo.org/index.php/scielo/...
# 1      https://preprints.scielo.org/index.php/scielo/...
# 2      https://preprints.scielo.org/index.php/scielo/...
# 3      https://preprints.scielo.org/index.php/scielo/...
# 4      https://preprints.scielo.org/index.php/scielo/...
# ...                                                  ...
# 11131  https://preprints.scielo.org/index.php/scielo/...
# 11132  https://preprints.scielo.org/index.php/scielo/...
# 11133  https://preprints.scielo.org/index.php/scielo/...
# 11134  https://preprints.scielo.org/index.php/scielo/...
# 11135  https://preprints.scielo.org/index.php/scielo/...
#
#                                                  Authors  \
# 0        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 2        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 3        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 4        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# ...                                                  ...
# 11131  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11132  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11133  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11134  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11135  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                       Published PDF Language  \
# 0      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 2      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 3      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 4      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# ...                                         ...          ...
# 11131  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11132  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11133  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11134  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11135  Submitted 04/06/2020 - Posted 04/08/2020          PDF
#
#                                                  PDF URL  Submitted  \
# 0      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 1      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 2      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 3      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 4      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# ...                                                  ...        ...
# 11131  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11132  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11133  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11134  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11135  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
#
#           Posted  Text ID           Discipline  \
# 0     2022-11-23  t000000  Biological Sciences
# 1     2022-11-23  t000000  Biological Sciences
# 2     2022-11-23  t000000  Biological Sciences
# 3     2022-11-23  t000000  Biological Sciences
# 4     2022-11-23  t000000  Biological Sciences
# ...          ...      ...                  ...
# 11131 2020-04-08  t000315      Health Sciences
# 11132 2020-04-08  t000315      Health Sciences
# 11133 2020-04-08  t000315      Health Sciences
# 11134 2020-04-08  t000315      Health Sciences
# 11135 2020-04-08  t000315      Health Sciences
#
#                                                  Section     Paragraph  \
# 0                                               Abstract   Paragraph 1
# 1                        Introduction, Literature Review   Paragraph 1
# 2                        Introduction, Literature Review   Paragraph 2
# 3                        Introduction, Literature Review   Paragraph 3
# 4                        Introduction, Literature Review   Paragraph 4
# ...                                                  ...           ...
# 11131  Literature Review, Methodology, Results, Discu...  Paragraph 14
# 11132  Literature Review, Methodology, Results, Discu...  Paragraph 15
# 11133  Literature Review, Methodology, Results, Discu...  Paragraph 16
# 11134  Literature Review, Methodology, Results, Discu...  Paragraph 17
# 11135                                   Acknowledgements   Paragraph 1
#
#                                           Text Paragraph  \
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      At the end of the era in which the plant Class...
# 2      Brazil is represented by Dennstaedtiaceae with...
# 3      Pteridium is spread all across the globe (exce...
# 4      In the State of Minas Gerais, Dennstaedtiaceae...
# ...                                                  ...
# 11131  During the Zika epidemic, Brazil led the disco...
# 11132  Although Brazil is attempting to implement mea...
# 11133  Regarding cultural differences, the use of mas...
# 11134  Physical distancing is a measure that should b...
# 11135  We thank Judith Recht for the critical review ...
#
#                                   Text Paragraph ChatGPT
# 0      As part of an ongoing project focused on the f...
# 1      At the end of the period when plant classifica...
# 2      In Brazil, Dennstaedtiaceae is represented by ...
# 3      Pteridium is distributed globally, with the ex...
# 4      In the state of Minas Gerais, the family Denns...
# ...                                                  ...
# 11131  During the Zika epidemic, Brazil was the first...
# 11132  Although Brazil is implementing measures to re...
# 11133  With respect to cultural differences, the use ...
# 11134  Physical distancing should be recommended at a...
# 11135  We thank Judith Recht for her critical review ...
#
# [10508 rows x 14 columns]

# %% [markdown]
# ### Balance the `Section`stratum

# %% [markdown]
# #### Inspect the sections by discipline

# %%
# List of disciplines
discipline = [
    'Health Sciences',
    'Biological Sciences',
    'Human Sciences',
    'Applied Social Sciences',
    'Linguistic, literature and arts'
]

# Create an empty dictionary to store unique sections for each discipline
unique_sections_by_discipline = {}

# Iterate through the disciplines
for d in discipline:
    # Slice the DataFrame based on the current discipline
    discipline_slice = df_el2ap[df_el2ap['Discipline'] == d]
    
    # Get unique sections, sorted in decreasing order
    unique_sections = sorted(discipline_slice['Section'].dropna().unique())
    
    # Store the result in the dictionary
    unique_sections_by_discipline[d] = unique_sections

# Display unique sections for each discipline
unique_sections_by_discipline
# Out:
# {'Health Sciences': ['Abstract',
#   'Acknowledgements',
#   'Conclusion',
#   'Discussion',
#   'Discussion, Conclusion',
#   'Introduction',
#   'Introduction, Literature Review',
#   'Introduction, Literature Review, Methodology',
#   'Introduction, Literature Review, Methodology, Results',
#   'Introduction, Literature Review, Methodology, Results, Discussion',
#   'Introduction, Literature Review, Methodology, Results, Discussion, Conclusion',
#   'Literature Review',
#   'Literature Review, Methodology',
#   'Literature Review, Methodology, Results',
#   'Literature Review, Methodology, Results, Discussion',
#   'Literature Review, Methodology, Results, Discussion, Conclusion',
#   'Methodology',
#   'Methodology, Results',
#   'Methodology, Results, Discussion',
#   'Methodology, Results, Discussion, Conclusion',
#   'Results',
#   'Results, Discussion',
#   'Results, Discussion, Conclusion'],
#  'Biological Sciences': ['Abstract',
#   'Acknowledgements',
#   'Conclusion',
#   'Discussion',
#   'Discussion, Conclusion',
#   'Introduction',
#   'Introduction, Literature Review',
#   'Introduction, Literature Review, Methodology, Results, Discussion, Conclusion',
#   'Literature Review, Methodology, Results, Discussion',
#   'Methodology',
#   'Methodology, Results, Discussion',
#   'Methodology, Results, Discussion, Conclusion',
#   'Results',
#   'Results, Discussion',
#   'Results, Discussion, Conclusion'],
#  'Human Sciences': ['Abstract',
#   'Acknowledgements',
#   'Comments to the Editor',
#   'Conclusion',
#   'Discussion',
#   'Discussion, Conclusion',
#   'Introduction',
#   'Introduction, Literature Review',
#   'Introduction, Literature Review, Methodology, Results, Discussion, Conclusion',
#   'Literature Review',
#   'Literature Review, Methodology, Results, Discussion',
#   'Methodology',
#   'Methodology, Results, Discussion',
#   'Methodology, Results, Discussion,',
#   'Results',
#   'Results, Discussion'],
#  'Applied Social Sciences': ['Abstract',
#   'Acknowledgements',
#   'Conclusion',
#   'Discussion',
#   'Discussion, Conclusion',
#   'Introduction',
#   'Introduction, Literature Review',
#   'Introduction, Literature Review, Methodology, Results',
#   'Introduction, Literature Review, Methodology, Results, Discussion, Conclusion',
#   'Literature Review',
#   'Literature Review, Methodology, Results, Discussion',
#   'Literature Review, Methodology, Results, Discussion, Conclusion',
#   'Methodology',
#   'Methodology, Results',
#   'Methodology, Results, Discussion',
#   'Results',
#   'Results, Discussion'],
#  'Linguistic, literature and arts': ['Abstract',
#   'Acknowledgements',
#   'Conclusion',
#   'Discussion',
#   'Introduction',
#   'Introduction, Literature Review',
#   'Literature Review',
#   'Literature Review, Methodology, Results, Discussion',
#   'Methodology',
#   'Methodology, Results, Discussion',
#   'Results',
#   'Results, Discussion']}

# %% [markdown]
# All of the sections in the `Linguistic, literature and arts` discipline are present in the other disciplines. The proposed strategy consists of aligning the patterns of sections in the `Linguistic, literature and arts` discipline with other disciplines by removing the divergent patterns in the `non_standard_articles` list.
#
# The divergent patterns consist of unusually organised articles:
# - `Introduction, Literature Review, Methodology, Results`: Texts that do not present a clear `Introduction` and conclude with a `Conclusion`;
# - `Introduction, Literature Review, Methodology, Results, Discussion, Conclusion`: Texts that consist of a single piece of text;
# - `Literature Review, Methodology, Results, Discussion, Conclusion`: Texts presenting a clear `Introduction` followed by a continuous text.

# %% [markdown]
# #### Inspect the non-standard texts by discipline

# %%
# Define the list of non-standard texts
non_standard_texts = [
    'Introduction, Literature Review, Methodology, Results',
    'Introduction, Literature Review, Methodology, Results, Discussion, Conclusion',
    'Literature Review, Methodology, Results, Discussion, Conclusion'
]

# Initialise an empty dictionary to store results by discipline
non_standard_by_discipline = {}

# Iterate through each unique discipline
for discipline in df_el2ap_balanced['Discipline'].unique():
    # Filter rows for the current discipline
    discipline_slice = df_el2ap_balanced[df_el2ap_balanced['Discipline'] == discipline]
    
    # Initialise a sub-dictionary for the current discipline
    non_standard_by_discipline[discipline] = {}
    
    # Iterate through the non-standard articles list
    for section in non_standard_texts:
        # Slice the DataFrame for the current section
        section_slice = discipline_slice[discipline_slice['Section'] == section]
        
        # Get unique Text IDs, sorted in increasing order
        unique_text_ids = sorted(section_slice['Text ID'].dropna().unique())
        
        # Add the result to the sub-dictionary
        non_standard_by_discipline[discipline][section] = unique_text_ids

# Display the results
non_standard_by_discipline
# Out:
# {'Biological Sciences': {'Introduction, Literature Review, Methodology, Results': [],
#   'Introduction, Literature Review, Methodology, Results, Discussion, Conclusion': ['t000124',
#    't000169',
#    't000174',
#    't000292'],
#   'Literature Review, Methodology, Results, Discussion, Conclusion': []},
#  'Applied Social Sciences': {'Introduction, Literature Review, Methodology, Results': ['t000074'],
#   'Introduction, Literature Review, Methodology, Results, Discussion, Conclusion': ['t000260'],
#   'Literature Review, Methodology, Results, Discussion, Conclusion': ['t000278']},
#  'Linguistic, literature and arts': {'Introduction, Literature Review, Methodology, Results': [],
#   'Introduction, Literature Review, Methodology, Results, Discussion, Conclusion': [],
#   'Literature Review, Methodology, Results, Discussion, Conclusion': []},
#  'Health Sciences': {'Introduction, Literature Review, Methodology, Results': ['t000268'],
#   'Introduction, Literature Review, Methodology, Results, Discussion, Conclusion': ['t000185',
#    't000192',
#    't000195',
#    't000199',
#    't000210',
#    't000212',
#    't000213',
#    't000214',
#    't000216',
#    't000217',
#    't000218',
#    't000222',
#    't000226',
#    't000228',
#    't000229',
#    't000231',
#    't000234',
#    't000237',
#    't000238',
#    't000239',
#    't000240',
#    't000241',
#    't000243',
#    't000244',
#    't000247',
#    't000251',
#    't000255',
#    't000256',
#    't000257',
#    't000258',
#    't000262',
#    't000267',
#    't000276',
#    't000280',
#    't000282',
#    't000291',
#    't000295',
#    't000300',
#    't000301',
#    't000302',
#    't000306',
#    't000308',
#    't000310',
#    't000311',
#    't000312'],
#   'Literature Review, Methodology, Results, Discussion, Conclusion': ['t000029',
#    't000207',
#    't000221',
#    't000223',
#    't000253',
#    't000277',
#    't000307',
#    't000315']},
#  'Human Sciences': {'Introduction, Literature Review, Methodology, Results': [],
#   'Introduction, Literature Review, Methodology, Results, Discussion, Conclusion': ['t000157'],
#   'Literature Review, Methodology, Results, Discussion, Conclusion': []}}

# %% [markdown]
# The texts with divergent patterns are more frequently found in the `Health Sciences` discipline. Even so, they are not so frequent compared to the whole corpus. Therefore, it is safe to exclude them.

# %% [markdown]
# #### Exclude the non-standard texts

# %%
# Initialise an empty set to store unique Text IDs
consolidated_text_ids = set()

# Iterate through the dictionary
for discipline, sections in non_standard_by_discipline.items():
    for section, text_ids in sections.items():
        # Add the Text IDs from the current section to the set
        consolidated_text_ids.update(text_ids)

# Convert the set to a sorted list in decreasing order
sorted_consolidated_text_ids = sorted(consolidated_text_ids)

# Display the result
sorted_consolidated_text_ids
# Out:
# ['t000029',
#  't000074',
#  't000124',
#  't000157',
#  't000169',
#  't000174',
#  't000185',
#  't000192',
#  't000195',
#  't000199',
#  't000207',
#  't000210',
#  't000212',
#  't000213',
#  't000214',
#  't000216',
#  't000217',
#  't000218',
#  't000221',
#  't000222',
#  't000223',
#  't000226',
#  't000228',
#  't000229',
#  't000231',
#  't000234',
#  't000237',
#  't000238',
#  't000239',
#  't000240',
#  't000241',
#  't000243',
#  't000244',
#  't000247',
#  't000251',
#  't000253',
#  't000255',
#  't000256',
#  't000257',
#  't000258',
#  't000260',
#  't000262',
#  't000267',
#  't000268',
#  't000276',
#  't000277',
#  't000278',
#  't000280',
#  't000282',
#  't000291',
#  't000292',
#  't000295',
#  't000300',
#  't000301',
#  't000302',
#  't000306',
#  't000307',
#  't000308',
#  't000310',
#  't000311',
#  't000312',
#  't000315']

# %%
# Drop rows where 'Text ID' is in the 'sorted_consolidated_text_ids' list
df_el2ap_balanced = df_el2ap_balanced[~df_el2ap_balanced['Text ID'].isin(sorted_consolidated_text_ids)]

# Display the filtered DataFrame
df_el2ap_balanced
# Out:
#                                                    Title  \
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 2      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 3      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 4      (Fern flora of Viçosa, Minas Gerais State, Bra...
# ...                                                  ...
# 11110  Coronavirus 2: Analysis of Regularity of Compl...
# 11111  Coronavirus 2: Analysis of Regularity of Compl...
# 11112  Coronavirus 2: Analysis of Regularity of Compl...
# 11113  Coronavirus 2: Analysis of Regularity of Compl...
# 11114  Coronavirus 2: Analysis of Regularity of Compl...
#
#                                                      URL  \
# 0      https://preprints.scielo.org/index.php/scielo/...
# 1      https://preprints.scielo.org/index.php/scielo/...
# 2      https://preprints.scielo.org/index.php/scielo/...
# 3      https://preprints.scielo.org/index.php/scielo/...
# 4      https://preprints.scielo.org/index.php/scielo/...
# ...                                                  ...
# 11110  https://preprints.scielo.org/index.php/scielo/...
# 11111  https://preprints.scielo.org/index.php/scielo/...
# 11112  https://preprints.scielo.org/index.php/scielo/...
# 11113  https://preprints.scielo.org/index.php/scielo/...
# 11114  https://preprints.scielo.org/index.php/scielo/...
#
#                                                Authors  \
# 0      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 2      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 3      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 4      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# ...                                                ...
# 11110                               Yuri Morales-López
# 11111                               Yuri Morales-López
# 11112                               Yuri Morales-López
# 11113                               Yuri Morales-López
# 11114                               Yuri Morales-López
#
#                                       Published PDF Language  \
# 0      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 2      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 3      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 4      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# ...                                         ...          ...
# 11110  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 11111  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 11112  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 11113  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 11114  Submitted 04/10/2020 - Posted 06/04/2020          PDF
#
#                                                  PDF URL  Submitted  \
# 0      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 1      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 2      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 3      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 4      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# ...                                                  ...        ...
# 11110  https://preprints.scielo.org/index.php/scielo/... 2020-04-10
# 11111  https://preprints.scielo.org/index.php/scielo/... 2020-04-10
# 11112  https://preprints.scielo.org/index.php/scielo/... 2020-04-10
# 11113  https://preprints.scielo.org/index.php/scielo/... 2020-04-10
# 11114  https://preprints.scielo.org/index.php/scielo/... 2020-04-10
#
#           Posted  Text ID           Discipline  \
# 0     2022-11-23  t000000  Biological Sciences
# 1     2022-11-23  t000000  Biological Sciences
# 2     2022-11-23  t000000  Biological Sciences
# 3     2022-11-23  t000000  Biological Sciences
# 4     2022-11-23  t000000  Biological Sciences
# ...          ...      ...                  ...
# 11110 2020-06-04  t000314  Biological Sciences
# 11111 2020-06-04  t000314  Biological Sciences
# 11112 2020-06-04  t000314  Biological Sciences
# 11113 2020-06-04  t000314  Biological Sciences
# 11114 2020-06-04  t000314  Biological Sciences
#
#                                Section    Paragraph  \
# 0                             Abstract  Paragraph 1
# 1      Introduction, Literature Review  Paragraph 1
# 2      Introduction, Literature Review  Paragraph 2
# 3      Introduction, Literature Review  Paragraph 3
# 4      Introduction, Literature Review  Paragraph 4
# ...                                ...          ...
# 11110              Results, Discussion  Paragraph 5
# 11111              Results, Discussion  Paragraph 6
# 11112              Results, Discussion  Paragraph 7
# 11113                       Conclusion  Paragraph 1
# 11114                       Conclusion  Paragraph 2
#
#                                           Text Paragraph  \
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      At the end of the era in which the plant Class...
# 2      Brazil is represented by Dennstaedtiaceae with...
# 3      Pteridium is spread all across the globe (exce...
# 4      In the State of Minas Gerais, Dennstaedtiaceae...
# ...                                                  ...
# 11110  The following is the complete genome analysis ...
# 11111  In this string size, Gene S (start) and Gene O...
# 11112  When calculating with a length interval of 28 ...
# 11113  During the analysis Gene S, Gene N and ORF10 w...
# 11114  The strategy developed here may offer insights...
#
#                                   Text Paragraph ChatGPT
# 0      As part of an ongoing project focused on the f...
# 1      At the end of the period when plant classifica...
# 2      In Brazil, Dennstaedtiaceae is represented by ...
# 3      Pteridium is distributed globally, with the ex...
# 4      In the state of Minas Gerais, the family Denns...
# ...                                                  ...
# 11110  The following section presents a comprehensive...
# 11111  Within this sequence length, both Gene S (star...
# 11112  When using a length interval of 28 nucleotides...
# 11113  During the analysis, Gene S, Gene N, and ORF10...
# 11114  The strategy developed in this study may provi...
#
# [9608 rows x 14 columns]

# %% [markdown]
# #### Reassess the balance

# %%
# Group by 'Discipline' and calculate the required metrics
df_balancing = df_el2ap_balanced.groupby('Discipline').agg(
    Text_Counts=('Text ID', lambda x: x.nunique()),  # Count unique Text IDs
    Paragraph_Counts=('Text ID', 'size')  # Count number of paragraphs (rows)
).reset_index()

# Rename the columns
df_balancing.rename(columns={
    'Text_Counts': 'Text Counts',
    'Paragraph_Counts': 'Paragraph Counts'
}, inplace=True)

# Sort the DataFrame by 'Paragraph Counts' in descending order
df_balancing = df_balancing.sort_values(by='Paragraph Counts', ascending=False).reset_index(drop=True)

# Add 'Average Paragraph Count per Text'
df_balancing['Average Paragraph Count per Text'] = df_balancing['Paragraph Counts'] / df_balancing['Text Counts']

# Add 'Balanced Paragraph Counts' using direct computation with the index
df_balancing['Balanced Paragraph Counts'] = df_balancing['Paragraph Counts'] * (df_balancing.index + 1)

# Display the DataFrame
df_balancing
# Out:
#                         Discipline  Text Counts  Paragraph Counts  \
# 0                  Health Sciences          132              4624
# 1              Biological Sciences           46              1454
# 2                   Human Sciences           26              1269
# 3          Applied Social Sciences           21              1231
# 4  Linguistic, literature and arts           15              1030
#
#    Average Paragraph Count per Text  Balanced Paragraph Counts
# 0                         35.030303                       4624
# 1                         31.608696                       2908
# 2                         48.807692                       3807
# 3                         58.619048                       4924
# 4                         68.666667                       5150

# %%
x_label = 'Number of Disciplines'
y_label = 'Balanced Paragraph Counts'
title = 'Balanced Paragraph Counts versus Number of Disciplines 2'
filename = 'df_el2ap_balanced_paragraph_counts_versus_number_of_disciplines2'
plot_filename = f"{filename}.png"

# %%
import matplotlib.pyplot as plt

# X-axis: Index + 1
x_axis = df_balancing.index + 1

# Y-axis: Balanced Paragraph Counts
y_axis = df_balancing['Balanced Paragraph Counts']

# Disciplines for labels
labels = df_balancing['Discipline']

# Plotting the bar plot
plt.figure(figsize=(10, 6))
plt.bar(x_axis, y_axis, color='royalblue')

# Adjust the y-axis range
plt.ylim(0, y_axis.max() * 1.4)  # Extend y-axis to 40% above the maximum value

# Adding labels and title
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(title)
plt.xticks(x_axis)  # Ensure all indices are shown

# Adding the labels for each bar
for i, label in enumerate(labels):
    plt.text(x=x_axis[i], y=y_axis[i] + (y_axis.max() * 0.02), s=label, ha='center', va='bottom', fontsize=8, rotation=45)

# Saving as an image
plt.savefig(f"{output_directory}/{plot_filename}", dpi=300, bbox_inches="tight")

# Show the plot
plt.show()

# %% [markdown]
# #### Create a LaTeX table

# %%
caption = title
label = f"tab:{filename}"
tex_filename = f"{filename}.tex"

# %%
tex_table = df_balancing.to_latex(index=False, longtable=True, decimal=',', caption=caption, label=label)

# %%
with open(f"{output_directory}/{tex_filename}", 'w', encoding='utf8', newline='\n') as file:
    file.write(tex_table)

# %% [markdown]
# `Health Sciences` still stands out. Therefore, the number of `Health Sciences` texts should be reduced. Since `Health Sciences` has an average paragraph count per text similar to `Biological Sciences`, the proposed solution is reducing the number of `Health Sciences` texts to 45.

# %% [markdown]
# #### Inspect the number of paragraphs per section per discipline

# %%
# Group by 'Discipline' and 'Section' to count the number of paragraphs
df_section_paragraph = df_el2ap_balanced.groupby(['Discipline', 'Section']).size().reset_index(name='Paragraph Count')

# Display the resulting DataFrame
df_section_paragraph
# Out:
#                          Discipline  \
# 0           Applied Social Sciences
# 1           Applied Social Sciences
# 2           Applied Social Sciences
# 3           Applied Social Sciences
# 4           Applied Social Sciences
# ..                              ...
# 70  Linguistic, literature and arts
# 71  Linguistic, literature and arts
# 72  Linguistic, literature and arts
# 73  Linguistic, literature and arts
# 74  Linguistic, literature and arts
#
#                                               Section  Paragraph Count
# 0                                            Abstract               28
# 1                                    Acknowledgements                9
# 2                                          Conclusion               94
# 3                                          Discussion               31
# 4                              Discussion, Conclusion                7
# ..                                                ...              ...
# 70  Literature Review, Methodology, Results, Discu...              197
# 71                                        Methodology               43
# 72                   Methodology, Results, Discussion              168
# 73                                            Results               46
# 74                                Results, Discussion              137
#
# [75 rows x 3 columns]

# %%
df_section_paragraph.to_excel(f"{output_directory}/df_section_paragraph.xlsx")

# %% [markdown]
# #### Inspect the top `Health Sciences` texts in terms of number of paragraphs

# %%
# Filter rows where 'Discipline' is 'Health Sciences'
health_sciences_slice = df_el2ap_balanced[df_el2ap_balanced['Discipline'] == 'Health Sciences']

# Group by 'Text ID' and count the number of paragraphs
df_top_health_sciences = health_sciences_slice.groupby('Text ID').size().reset_index(name='Paragraph Count')

# Sort by 'Paragraph Count' in descending order
df_top_health_sciences = df_top_health_sciences.sort_values(by='Paragraph Count', ascending=False).reset_index(drop=True)

# Display the resulting DataFrame
df_top_health_sciences
# Out:
#      Text ID  Paragraph Count
# 0    t000013               96
# 1    t000025               84
# 2    t000133               80
# 3    t000105               69
# 4    t000030               68
# ..       ...              ...
# 127  t000180               13
# 128  t000273               12
# 129  t000235               10
# 130  t000296                6
# 131  t000219                6
#
# [132 rows x 2 columns]

# %% [markdown]
# ##### Export to a file

# %%
df_top_health_sciences.to_excel(f"{output_directory}/df_top_health_sciences.xlsx")

# %% [markdown]
# #### Randomly select 45 `Health Sciences` texts to be retained

# %%
# Ensure 'Text ID' column has enough unique items
if len(df_top_health_sciences['Text ID'].unique()) >= 45:
    # Generate a random sample of 45 'Text ID's
    random_text_ids = random.sample(list(df_top_health_sciences['Text ID'].unique()), 45)
else:
    print("Not enough unique 'Text ID' values to sample 45 items.")

# Display the random sample
random_text_ids
# Out:
# ['t000305',
#  't000235',
#  't000193',
#  't000204',
#  't000091',
#  't000299',
#  't000274',
#  't000275',
#  't000189',
#  't000083',
#  't000288',
#  't000105',
#  't000285',
#  't000135',
#  't000294',
#  't000198',
#  't000040',
#  't000095',
#  't000273',
#  't000211',
#  't000171',
#  't000250',
#  't000063',
#  't000272',
#  't000177',
#  't000200',
#  't000121',
#  't000154',
#  't000309',
#  't000043',
#  't000246',
#  't000283',
#  't000203',
#  't000025',
#  't000271',
#  't000092',
#  't000109',
#  't000141',
#  't000097',
#  't000116',
#  't000287',
#  't000188',
#  't000035',
#  't000293',
#  't000115']

# %% [markdown]
# #### Build the list of exclusion of `Health Sciences` texts

# %%
# Get all 'Text ID' values from the 'df_top_health_sciences' DataFrame
all_text_ids = df_top_health_sciences['Text ID'].unique()

# Identify 'Text ID' values to be excluded
excluded_text_ids = [text_id for text_id in all_text_ids if text_id not in random_text_ids]

# Display the list of 'Text ID's to be excluded
#excluded_text_ids

# %% [markdown]
# #### Exclude the `Health Sciences` texts

# %%
# Exclude rows where 'Text ID' is in the 'excluded_text_ids' list
df_el2ap_balanced = df_el2ap_balanced[~df_el2ap_balanced['Text ID'].isin(excluded_text_ids)]

# Display the resulting DataFrame
#df_el2ap_balanced

# %% [markdown]
# #### Reassess the balance

# %%
# Group by 'Discipline' and calculate the required metrics
df_balancing = df_el2ap_balanced.groupby('Discipline').agg(
    Text_Counts=('Text ID', lambda x: x.nunique()),  # Count unique Text IDs
    Paragraph_Counts=('Text ID', 'size')  # Count number of paragraphs (rows)
).reset_index()

# Rename the columns
df_balancing.rename(columns={
    'Text_Counts': 'Text Counts',
    'Paragraph_Counts': 'Paragraph Counts'
}, inplace=True)

# Sort the DataFrame by 'Paragraph Counts' in descending order
df_balancing = df_balancing.sort_values(by='Paragraph Counts', ascending=False).reset_index(drop=True)

# Add 'Average Paragraph Count per Text'
df_balancing['Average Paragraph Count per Text'] = df_balancing['Paragraph Counts'] / df_balancing['Text Counts']

# Add 'Balanced Paragraph Counts' using direct computation with the index
df_balancing['Balanced Paragraph Counts'] = df_balancing['Paragraph Counts'] * (df_balancing.index + 1)

# Display the DataFrame
df_balancing
# Out:
#                         Discipline  Text Counts  Paragraph Counts  \
# 0                  Health Sciences           45              1684
# 1              Biological Sciences           46              1454
# 2                   Human Sciences           26              1269
# 3          Applied Social Sciences           21              1231
# 4  Linguistic, literature and arts           15              1030
#
#    Average Paragraph Count per Text  Balanced Paragraph Counts
# 0                         37.422222                       1684
# 1                         31.608696                       2908
# 2                         48.807692                       3807
# 3                         58.619048                       4924
# 4                         68.666667                       5150

# %%
# Group by 'Discipline' and 'Section' to count the number of paragraphs
df_section_paragraph = df_el2ap_balanced.groupby(['Discipline', 'Section']).size().reset_index(name='Paragraph Count')

# Display the resulting DataFrame
df_section_paragraph
# Out:
#                          Discipline  \
# 0           Applied Social Sciences
# 1           Applied Social Sciences
# 2           Applied Social Sciences
# 3           Applied Social Sciences
# 4           Applied Social Sciences
# ..                              ...
# 65  Linguistic, literature and arts
# 66  Linguistic, literature and arts
# 67  Linguistic, literature and arts
# 68  Linguistic, literature and arts
# 69  Linguistic, literature and arts
#
#                                               Section  Paragraph Count
# 0                                            Abstract               28
# 1                                    Acknowledgements                9
# 2                                          Conclusion               94
# 3                                          Discussion               31
# 4                              Discussion, Conclusion                7
# ..                                                ...              ...
# 65  Literature Review, Methodology, Results, Discu...              197
# 66                                        Methodology               43
# 67                   Methodology, Results, Discussion              168
# 68                                            Results               46
# 69                                Results, Discussion              137
#
# [70 rows x 3 columns]

# %%
# Filter rows where 'Discipline' is 'Health Sciences'
health_sciences_slice = df_el2ap_balanced[df_el2ap_balanced['Discipline'] == 'Health Sciences']

# Group by 'Text ID' and count the number of paragraphs
df_top_health_sciences = health_sciences_slice.groupby('Text ID').size().reset_index(name='Paragraph Count')

# Sort by 'Paragraph Count' in descending order
df_top_health_sciences = df_top_health_sciences.sort_values(by='Paragraph Count', ascending=False).reset_index(drop=True)

# Display the resulting DataFrame
df_top_health_sciences
# Out:
#     Text ID  Paragraph Count
# 0   t000025               84
# 1   t000105               69
# 2   t000109               63
# 3   t000177               60
# 4   t000193               57
# 5   t000097               55
# 6   t000035               51
# 7   t000211               49
# 8   t000091               48
# 9   t000204               47
# 10  t000083               46
# 11  t000200               46
# 12  t000189               43
# 13  t000299               43
# 14  t000271               41
# 15  t000246               41
# 16  t000309               40
# 17  t000294               38
# 18  t000305               37
# 19  t000141               37
# 20  t000274               37
# 21  t000171               36
# 22  t000154               35
# 23  t000063               35
# 24  t000203               35
# 25  t000250               34
# 26  t000288               34
# 27  t000115               34
# 28  t000272               31
# 29  t000116               30
# 30  t000095               30
# 31  t000121               29
# 32  t000040               28
# 33  t000188               27
# 34  t000092               27
# 35  t000285               26
# 36  t000043               26
# 37  t000293               24
# 38  t000198               23
# 39  t000135               23
# 40  t000275               23
# 41  t000283               22
# 42  t000287               18
# 43  t000273               12
# 44  t000235               10

# %% [markdown]
# ##### Export to a file

# %%
df_section_paragraph.to_excel(f"{output_directory}/df_section_paragraph2.xlsx")

# %% [markdown]
# ## Finalised `EL2AP` and `AI-EL2AP` corpora

# %% [markdown]
# **Important**: Due to the random component that was introduced, the corpus changes every time this notebook is reprocessed.

# %%
df_el2ap_balanced
# Out:
#                                                    Title  \
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 2      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 3      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 4      (Fern flora of Viçosa, Minas Gerais State, Bra...
# ...                                                  ...
# 11500  Coronavirus 2: Analysis of Regularity of Compl...
# 11501  Coronavirus 2: Analysis of Regularity of Compl...
# 11502  Coronavirus 2: Analysis of Regularity of Compl...
# 11503  Coronavirus 2: Analysis of Regularity of Compl...
# 11504  Coronavirus 2: Analysis of Regularity of Compl...
#
#                                                      URL  \
# 0      https://preprints.scielo.org/index.php/scielo/...
# 1      https://preprints.scielo.org/index.php/scielo/...
# 2      https://preprints.scielo.org/index.php/scielo/...
# 3      https://preprints.scielo.org/index.php/scielo/...
# 4      https://preprints.scielo.org/index.php/scielo/...
# ...                                                  ...
# 11500  https://preprints.scielo.org/index.php/scielo/...
# 11501  https://preprints.scielo.org/index.php/scielo/...
# 11502  https://preprints.scielo.org/index.php/scielo/...
# 11503  https://preprints.scielo.org/index.php/scielo/...
# 11504  https://preprints.scielo.org/index.php/scielo/...
#
#                                                Authors  \
# 0      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 2      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 3      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 4      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# ...                                                ...
# 11500                               Yuri Morales-López
# 11501                               Yuri Morales-López
# 11502                               Yuri Morales-López
# 11503                               Yuri Morales-López
# 11504                               Yuri Morales-López
#
#                                       Published PDF Language  \
# 0      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 2      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 3      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 4      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# ...                                         ...          ...
# 11500  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 11501  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 11502  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 11503  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 11504  Submitted 04/10/2020 - Posted 06/04/2020          PDF
#
#                                                  PDF URL  Submitted  \
# 0      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 1      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 2      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 3      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 4      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# ...                                                  ...        ...
# 11500  https://preprints.scielo.org/index.php/scielo/... 2020-04-10
# 11501  https://preprints.scielo.org/index.php/scielo/... 2020-04-10
# 11502  https://preprints.scielo.org/index.php/scielo/... 2020-04-10
# 11503  https://preprints.scielo.org/index.php/scielo/... 2020-04-10
# 11504  https://preprints.scielo.org/index.php/scielo/... 2020-04-10
#
#           Posted  Text ID           Discipline  \
# 0     2022-11-23  t000000  Biological Sciences
# 1     2022-11-23  t000000  Biological Sciences
# 2     2022-11-23  t000000  Biological Sciences
# 3     2022-11-23  t000000  Biological Sciences
# 4     2022-11-23  t000000  Biological Sciences
# ...          ...      ...                  ...
# 11500 2020-06-04  t000314  Biological Sciences
# 11501 2020-06-04  t000314  Biological Sciences
# 11502 2020-06-04  t000314  Biological Sciences
# 11503 2020-06-04  t000314  Biological Sciences
# 11504 2020-06-04  t000314  Biological Sciences
#
#                                Section    Paragraph  \
# 0                             Abstract  Paragraph 1
# 1      Introduction, Literature Review  Paragraph 1
# 2      Introduction, Literature Review  Paragraph 2
# 3      Introduction, Literature Review  Paragraph 3
# 4      Introduction, Literature Review  Paragraph 4
# ...                                ...          ...
# 11500              Results, Discussion  Paragraph 5
# 11501              Results, Discussion  Paragraph 6
# 11502              Results, Discussion  Paragraph 7
# 11503                       Conclusion  Paragraph 1
# 11504                       Conclusion  Paragraph 2
#
#                                           Text Paragraph  \
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      At the end of the era in which the plant Class...
# 2      Brazil is represented by Dennstaedtiaceae with...
# 3      Pteridium is spread all across the globe (exce...
# 4      In the State of Minas Gerais, Dennstaedtiaceae...
# ...                                                  ...
# 11500  The following is the complete genome analysis ...
# 11501  In this string size, Gene S (start) and Gene O...
# 11502  When calculating with a length interval of 28 ...
# 11503  During the analysis Gene S, Gene N and ORF10 w...
# 11504  The strategy developed here may offer insights...
#
#                                   Text Paragraph ChatGPT
# 0      As part of an ongoing project focused on the f...
# 1      At the end of the period when plant classifica...
# 2      In Brazil, Dennstaedtiaceae is represented by ...
# 3      Pteridium is distributed globally, with the ex...
# 4      In the state of Minas Gerais, the family Denns...
# ...                                                  ...
# 11500  The following section presents a comprehensive...
# 11501  Within this sequence length, both Gene S (star...
# 11502  When using a length interval of 28 nucleotides...
# 11503  During the analysis, Gene S, Gene N, and ORF10...
# 11504  The strategy developed in this study may provi...
#
# [6668 rows x 14 columns]

# %% [markdown]
# ### Create the column `Section Code`

# %%
# Create a list of sections sorted in increasing order
section_list = sorted(df_el2ap_balanced['Section'].dropna().unique())

# Create the dictionary with scheme 's1', 's2', etc.
section_dict = {f"s{i+1}": section for i, section in enumerate(section_list)}

# Display the dictionary
section_dict
# Out:
# {'s1': 'Abstract',
#  's2': 'Acknowledgements',
#  's3': 'Comments to the Editor',
#  's4': 'Conclusion',
#  's5': 'Discussion',
#  's6': 'Discussion, Conclusion',
#  's7': 'Introduction',
#  's8': 'Introduction, Literature Review',
#  's9': 'Introduction, Literature Review, Methodology',
#  's10': 'Introduction, Literature Review, Methodology, Results, Discussion',
#  's11': 'Literature Review',
#  's12': 'Literature Review, Methodology, Results',
#  's13': 'Literature Review, Methodology, Results, Discussion',
#  's14': 'Methodology',
#  's15': 'Methodology, Results',
#  's16': 'Methodology, Results, Discussion',
#  's17': 'Methodology, Results, Discussion,',
#  's18': 'Methodology, Results, Discussion, Conclusion',
#  's19': 'Results',
#  's20': 'Results, Discussion',
#  's21': 'Results, Discussion, Conclusion'}

# %%
# Reverse the dictionary: swap keys and values
reversed_section_dict = {value: key for key, value in section_dict.items()}

# Create the 'Section Code' column based on the 'Section' column
df_el2ap_balanced['Section Code'] = df_el2ap_balanced['Section'].map(reversed_section_dict)

# Display the updated DataFrame
df_el2ap_balanced
# Out:
#                                                   Title  \
# 0     (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1     (Fern flora of Viçosa, Minas Gerais State, Bra...
# 2     (Fern flora of Viçosa, Minas Gerais State, Bra...
# 3     (Fern flora of Viçosa, Minas Gerais State, Bra...
# 4     (Fern flora of Viçosa, Minas Gerais State, Bra...
# ...                                                 ...
# 6663  Coronavirus 2: Analysis of Regularity of Compl...
# 6664  Coronavirus 2: Analysis of Regularity of Compl...
# 6665  Coronavirus 2: Analysis of Regularity of Compl...
# 6666  Coronavirus 2: Analysis of Regularity of Compl...
# 6667  Coronavirus 2: Analysis of Regularity of Compl...
#
#                                                     URL  \
# 0     https://preprints.scielo.org/index.php/scielo/...
# 1     https://preprints.scielo.org/index.php/scielo/...
# 2     https://preprints.scielo.org/index.php/scielo/...
# 3     https://preprints.scielo.org/index.php/scielo/...
# 4     https://preprints.scielo.org/index.php/scielo/...
# ...                                                 ...
# 6663  https://preprints.scielo.org/index.php/scielo/...
# 6664  https://preprints.scielo.org/index.php/scielo/...
# 6665  https://preprints.scielo.org/index.php/scielo/...
# 6666  https://preprints.scielo.org/index.php/scielo/...
# 6667  https://preprints.scielo.org/index.php/scielo/...
#
#                                               Authors  \
# 0     Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1     Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 2     Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 3     Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 4     Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# ...                                               ...
# 6663                               Yuri Morales-López
# 6664                               Yuri Morales-López
# 6665                               Yuri Morales-López
# 6666                               Yuri Morales-López
# 6667                               Yuri Morales-López
#
#                                      Published PDF Language  \
# 0     Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1     Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 2     Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 3     Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 4     Submitted 11/22/2022 - Posted 11/23/2022          PDF
# ...                                        ...          ...
# 6663  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 6664  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 6665  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 6666  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 6667  Submitted 04/10/2020 - Posted 06/04/2020          PDF
#
#                                                 PDF URL  Submitted     Posted  \
# 0     https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 1     https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 2     https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 3     https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 4     https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# ...                                                 ...        ...        ...
# 6663  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 6664  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 6665  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 6666  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 6667  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
#
#       Text ID           Discipline                          Section  \
# 0     t000000  Biological Sciences                         Abstract
# 1     t000000  Biological Sciences  Introduction, Literature Review
# 2     t000000  Biological Sciences  Introduction, Literature Review
# 3     t000000  Biological Sciences  Introduction, Literature Review
# 4     t000000  Biological Sciences  Introduction, Literature Review
# ...       ...                  ...                              ...
# 6663  t000314  Biological Sciences              Results, Discussion
# 6664  t000314  Biological Sciences              Results, Discussion
# 6665  t000314  Biological Sciences              Results, Discussion
# 6666  t000314  Biological Sciences                       Conclusion
# 6667  t000314  Biological Sciences                       Conclusion
#
#         Paragraph                                     Text Paragraph  \
# 0     Paragraph 1  (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1     Paragraph 1  At the end of the era in which the plant Class...
# 2     Paragraph 2  Brazil is represented by Dennstaedtiaceae with...
# 3     Paragraph 3  Pteridium is spread all across the globe (exce...
# 4     Paragraph 4  In the State of Minas Gerais, Dennstaedtiaceae...
# ...           ...                                                ...
# 6663  Paragraph 5  The following is the complete genome analysis ...
# 6664  Paragraph 6  In this string size, Gene S (start) and Gene O...
# 6665  Paragraph 7  When calculating with a length interval of 28 ...
# 6666  Paragraph 1  During the analysis Gene S, Gene N and ORF10 w...
# 6667  Paragraph 2  The strategy developed here may offer insights...
#
#                                  Text Paragraph ChatGPT Section Code
# 0     As part of an ongoing project focused on the f...           s1
# 1     At the end of the period when plant classifica...           s8
# 2     In Brazil, Dennstaedtiaceae is represented by ...           s8
# 3     Pteridium is distributed globally, with the ex...           s8
# 4     In the state of Minas Gerais, the family Denns...           s8
# ...                                                 ...          ...
# 6663  The following section presents a comprehensive...          s20
# 6664  Within this sequence length, both Gene S (star...          s20
# 6665  When using a length interval of 28 nucleotides...          s20
# 6666  During the analysis, Gene S, Gene N, and ORF10...           s4
# 6667  The strategy developed in this study may provi...           s4
#
# [6668 rows x 15 columns]

# %% [markdown]
# ### Create the column `Paragraph Code`

# %%
# Create the 'Paragraph Code' column by extracting the numeric part and prepending 'p'
df_el2ap_balanced['Paragraph Code'] = df_el2ap_balanced['Paragraph'].apply(lambda x: f"p{''.join(filter(str.isdigit, str(x)))}")

# Display the updated DataFrame
df_el2ap_balanced
# Out:
#                                                   Title  \
# 0     (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1     (Fern flora of Viçosa, Minas Gerais State, Bra...
# 2     (Fern flora of Viçosa, Minas Gerais State, Bra...
# 3     (Fern flora of Viçosa, Minas Gerais State, Bra...
# 4     (Fern flora of Viçosa, Minas Gerais State, Bra...
# ...                                                 ...
# 6663  Coronavirus 2: Analysis of Regularity of Compl...
# 6664  Coronavirus 2: Analysis of Regularity of Compl...
# 6665  Coronavirus 2: Analysis of Regularity of Compl...
# 6666  Coronavirus 2: Analysis of Regularity of Compl...
# 6667  Coronavirus 2: Analysis of Regularity of Compl...
#
#                                                     URL  \
# 0     https://preprints.scielo.org/index.php/scielo/...
# 1     https://preprints.scielo.org/index.php/scielo/...
# 2     https://preprints.scielo.org/index.php/scielo/...
# 3     https://preprints.scielo.org/index.php/scielo/...
# 4     https://preprints.scielo.org/index.php/scielo/...
# ...                                                 ...
# 6663  https://preprints.scielo.org/index.php/scielo/...
# 6664  https://preprints.scielo.org/index.php/scielo/...
# 6665  https://preprints.scielo.org/index.php/scielo/...
# 6666  https://preprints.scielo.org/index.php/scielo/...
# 6667  https://preprints.scielo.org/index.php/scielo/...
#
#                                               Authors  \
# 0     Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1     Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 2     Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 3     Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 4     Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# ...                                               ...
# 6663                               Yuri Morales-López
# 6664                               Yuri Morales-López
# 6665                               Yuri Morales-López
# 6666                               Yuri Morales-López
# 6667                               Yuri Morales-López
#
#                                      Published PDF Language  \
# 0     Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1     Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 2     Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 3     Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 4     Submitted 11/22/2022 - Posted 11/23/2022          PDF
# ...                                        ...          ...
# 6663  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 6664  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 6665  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 6666  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 6667  Submitted 04/10/2020 - Posted 06/04/2020          PDF
#
#                                                 PDF URL  Submitted     Posted  \
# 0     https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 1     https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 2     https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 3     https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 4     https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# ...                                                 ...        ...        ...
# 6663  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 6664  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 6665  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 6666  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 6667  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
#
#       Text ID           Discipline                          Section  \
# 0     t000000  Biological Sciences                         Abstract
# 1     t000000  Biological Sciences  Introduction, Literature Review
# 2     t000000  Biological Sciences  Introduction, Literature Review
# 3     t000000  Biological Sciences  Introduction, Literature Review
# 4     t000000  Biological Sciences  Introduction, Literature Review
# ...       ...                  ...                              ...
# 6663  t000314  Biological Sciences              Results, Discussion
# 6664  t000314  Biological Sciences              Results, Discussion
# 6665  t000314  Biological Sciences              Results, Discussion
# 6666  t000314  Biological Sciences                       Conclusion
# 6667  t000314  Biological Sciences                       Conclusion
#
#         Paragraph                                     Text Paragraph  \
# 0     Paragraph 1  (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1     Paragraph 1  At the end of the era in which the plant Class...
# 2     Paragraph 2  Brazil is represented by Dennstaedtiaceae with...
# 3     Paragraph 3  Pteridium is spread all across the globe (exce...
# 4     Paragraph 4  In the State of Minas Gerais, Dennstaedtiaceae...
# ...           ...                                                ...
# 6663  Paragraph 5  The following is the complete genome analysis ...
# 6664  Paragraph 6  In this string size, Gene S (start) and Gene O...
# 6665  Paragraph 7  When calculating with a length interval of 28 ...
# 6666  Paragraph 1  During the analysis Gene S, Gene N and ORF10 w...
# 6667  Paragraph 2  The strategy developed here may offer insights...
#
#                                  Text Paragraph ChatGPT Section Code  \
# 0     As part of an ongoing project focused on the f...           s1
# 1     At the end of the period when plant classifica...           s8
# 2     In Brazil, Dennstaedtiaceae is represented by ...           s8
# 3     Pteridium is distributed globally, with the ex...           s8
# 4     In the state of Minas Gerais, the family Denns...           s8
# ...                                                 ...          ...
# 6663  The following section presents a comprehensive...          s20
# 6664  Within this sequence length, both Gene S (star...          s20
# 6665  When using a length interval of 28 nucleotides...          s20
# 6666  During the analysis, Gene S, Gene N, and ORF10...           s4
# 6667  The strategy developed in this study may provi...           s4
#
#      Paragraph Code
# 0                p1
# 1                p1
# 2                p2
# 3                p3
# 4                p4
# ...             ...
# 6663             p5
# 6664             p6
# 6665             p7
# 6666             p1
# 6667             p2
#
# [6668 rows x 16 columns]

# %% [markdown]
# ### Export to a file

# %%
df_el2ap_balanced.to_json(f"{output_directory}/df_el2ap_balanced.jsonl", orient='records', lines=True)

# %%
df_el2ap_balanced.to_excel(f"{output_directory}/df_el2ap_balanced.xlsx")

# %% [markdown]
# ## Word Count

# %% [markdown]
# ### Import the data into a DataFrame

# %%
df_el2ap_balanced = pd.read_json(f"{output_directory}/df_el2ap_balanced.jsonl", lines=True)

# %%
df_el2ap_balanced['Submitted'] = pd.to_datetime(df_el2ap_balanced['Submitted'], unit='ms')
df_el2ap_balanced['Posted'] = pd.to_datetime(df_el2ap_balanced['Posted'], unit='ms')

# %% [markdown]
# ### Calculate word counts for columns `Text Paragraph` and `Text Paragraph ChatGPT`

# %%
# Download the required NLTK data (only if you haven't already)
nltk.download('punkt')

# Create the new column 'Text Paragraph Word Count'
df_el2ap_balanced['Text Paragraph Word Count'] = df_el2ap_balanced['Text Paragraph'].apply(lambda x: len(word_tokenize(str(x))))

# Create the new column 'Text Paragraph ChatGPT Word Count'
df_el2ap_balanced['Text Paragraph ChatGPT Word Count'] = df_el2ap_balanced['Text Paragraph ChatGPT'].apply(lambda x: len(word_tokenize(str(x))))
# Out:
# [nltk_data] Downloading package punkt to /home/eyamrog/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### `EL2AP` and `AI-EL2AP` corpora number of texts

# %%
# Calculate the number of unique values in the 'Text ID' column
num_unique_text_ids = df_el2ap_balanced['Text ID'].nunique()

# Display the result
num_unique_text_ids
# Out:
# 153

# %% [markdown]
# ### `EL2AP` and `AI-EL2AP` corpora number of paragraphs

# %%
df_el2ap_balanced.shape[0]
# Out:
# 6668

# %% [markdown]
# ### `EL2AP` corpus number of tokens

# %%
# Calculate the total number of words
total_word_count = df_el2ap_balanced['Text Paragraph Word Count'].sum()

# Display the total word count
total_word_count
# Out:
# 746066

# %% [markdown]
# ### `AI-EL2AP` corpus number of tokens

# %%
# Calculate the total number of words
total_word_count_chatgpt = df_el2ap_balanced['Text Paragraph ChatGPT Word Count'].sum()

# Display the total word count
total_word_count_chatgpt
# Out:
# 747754

# %% [markdown]
# ## Prepare data for tagging

# %% [markdown]
# ### Import the data into a DataFrame

# %%
df_el2ap_balanced = pd.read_json(f"{output_directory}/df_el2ap_balanced.jsonl", lines=True)

# %%
df_el2ap_balanced['Submitted'] = pd.to_datetime(df_el2ap_balanced['Submitted'], unit='ms')
df_el2ap_balanced['Posted'] = pd.to_datetime(df_el2ap_balanced['Posted'], unit='ms')

# %% [markdown]
# ### Prepare `EL2AP` data for tagging

# %% [markdown]
# - Export each paragraph in the column 'Text Paragraph' of the 'df_el2ap_balanced' DataFrame to individual text files;
# - Introduce a '\n' every 10 words so that each file is organised in lines of 10 words;
# - Organise the files into directories sequentially named 'el2ap/el2ap_1', 'el2ap/el2ap_2', etc., in the 'output_directory', with 1,000 files each.

# %%
# Counter for directories and files
dir_count = 1
file_count = 0

# Function to split text into lines of 10 words
def format_paragraph(text):
    words = text.split()  # Split the paragraph into words
    lines = [' '.join(words[i:i+10]) for i in range(0, len(words), 10)]  # Group words in chunks of 10
    return '\n'.join(lines)  # Join lines with a newline character

# Iterate through the DataFrame rows
for index, row in df_el2ap_balanced.iterrows():
    # Check if a new directory is needed
    if file_count % 1000 == 0:
        dir_name = f"{output_directory}/el2ap/el2ap_{dir_count}"
        os.makedirs(dir_name, exist_ok=True)  # Create the directory if it doesn't exist
        dir_count += 1

    # Generate the file name
    file_name = f"{dir_name}/{row['Text ID']}_{row['Section Code']}_{row['Paragraph Code']}_el2ap.txt"
    
    # Write the formatted paragraph to the file
    with open(file_name, 'w', encoding='utf-8') as file:
        formatted_paragraph = format_paragraph(str(row['Text Paragraph']))
        file.write(formatted_paragraph)
    
    # Increment the file counter
    file_count += 1

# %% [markdown]
# ### Prepare `AI-EL2AP` data for tagging

# %% [markdown]
# - Export each paragraph in the column 'Text Paragraph ChatGPT' of the 'df_el2ap_balanced' DataFrame to individual text files;
# - Introduce a '\n' every 10 words so that each file is organised in lines of 10 words;
# - Organise the files into directories sequentially named 'ai-el2ap/ai-el2ap_1', 'ai-el2ap/ai-el2ap_2', etc., in the 'output_directory', with 1,000 files each.

# %%
# Counter for directories and files
dir_count = 1
file_count = 0

# Function to split text into lines of 10 words
def format_paragraph(text):
    words = text.split()  # Split the paragraph into words
    lines = [' '.join(words[i:i+10]) for i in range(0, len(words), 10)]  # Group words in chunks of 10
    return '\n'.join(lines)  # Join lines with a newline character

# Iterate through the DataFrame rows
for index, row in df_el2ap_balanced.iterrows():
    # Check if a new directory is needed
    if file_count % 1000 == 0:
        dir_name = f"{output_directory}/ai-el2ap/ai-el2ap_{dir_count}"
        os.makedirs(dir_name, exist_ok=True)  # Create the directory if it doesn't exist
        dir_count += 1

    # Generate the file name
    file_name = f"{dir_name}/{row['Text ID']}_{row['Section Code']}_{row['Paragraph Code']}_ai-el2ap.txt"
    
    # Write the formatted paragraph to the file
    with open(file_name, 'w', encoding='utf-8') as file:
        formatted_paragraph = format_paragraph(str(row['Text Paragraph ChatGPT']))
        file.write(formatted_paragraph)
    
    # Increment the file counter
    file_count += 1
